# %%
import pandas as pd
from sklearn.svm import SVC
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
import xgboost
from sklearn.cross_validation import StratifiedKFold
from scipy.stats import randint,uniform
# Out:
# C:\Users\ANURAG NIDHI\Anaconda3\lib\site-packages\sklearn\cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
import numpy as np
from sklearn.ensemble import VotingClassifier,RandomForestClassifier
from sklearn.preprocessing import StandardScaler

# %%
df1=pd.read_csv("train.csv")

# %%
#df1.isnull().sum()
df1
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0               842     0          2.2         0   1       0           7
# 1              1021     1          0.5         1   0       1          53
# 2               563     1          0.5         1   2       1          41
# 3               615     1          2.5         0   0       0          10
# 4              1821     1          1.2         0  13       1          44
# 5              1859     0          0.5         1   3       0          22
# 6              1821     0          1.7         0   4       1          10
# 7              1954     0          0.5         1   0       0          24
# 8              1445     1          0.5         0   0       0          53
# 9               509     1          0.6         1   2       1           9
# 10              769     1          2.9         1   0       0           9
# 11             1520     1          2.2         0   5       1          33
# ...

# %%
#df1.drop('mobile_wt',inplace=True,axis=1)
#df1.drop('three_g',inplace=True,axis=1)
#df1.drop('m_dep',inplace=True,axis=1)
#df1.drop('blue',inplace=True,axis=1)
#df1.drop('wifi',inplace=True,axis=1)
#df1.drop('talk_time',inplace=True,axis=1)
#X_train=df1.drop('price_range',axis=1)
#y_train=df1['price_range']
#df1=df1[['battery_power','clock_speed','fc','int_memory', 'm_dep', 'mobile_wt','pc', 'px_height','px_width', 'ram', 'sc_h', 'sc_w', 'talk_time','n_cores','price_range']]
df1=df1[['battery_power','int_memory', 'mobile_wt', 'px_height','px_width', 'ram', 'sc_w', 'talk_time','price_range']]

# %%
from xgboost import XGBClassifier
from sklearn.preprocessing import MinMaxScaler
sc = MinMaxScaler()
sc.fit(df1.drop('price_range',axis=1))
X_train = sc.transform(df1.drop('price_range',axis=1))
y_train=df1['price_range']
cv=StratifiedKFold(y_train,n_folds=10,shuffle=True,random_state=321)

# %%
#xgb = XGBClassifier(objective='multi:softmax', n_estimators=200,seed=123,learning_rate=0.15,max_depth=5,colsample_bytree=1,subsample=1)
rdf= RandomForestClassifier(n_estimators=100,random_state=0,criterion='entropy')
svc=SVC()
from sklearn.grid_search import GridSearchCV,RandomizedSearchCV
param_grid = param_grid = {'C': [0.01,0.1,1, 10, 100, 1000], 'gamma': [10,1,0.1,0.01,0.001,0.0001], 'kernel': ['rbf']} 
grid = GridSearchCV(SVC(),param_grid=param_grid,verbose=3)

#pca=PCA(0.95)
#principalcomp=pca.fit_transform(X_train)
#pca.explained_variance_ratio_
#principalcomp.shape
#pca.n_components_
#principaldf=pd.DataFrame(data=principalcomp)

# %%
grid.fit(X_train,y_train)

# %%
df2=pd.read_csv('test.csv')
print("best accuracy obtained: {0}".format(bst_grid.best_score_))
print("parameters")
for key,value in bst_grid.best_params_.items():
    print("\t{}: {}".format(key,value))
rs_grid.best_params_

# %%
df2.head()
# Out:
#    id  battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0   1           1043     1          1.8         1  14       0           5
# 1   2            841     1          0.5         1   4       1          61
# 2   3           1807     1          2.8         0   1       0          27
# 3   4           1546     0          0.5         1  18       1          25
# 4   5           1434     0          1.4         0  11       1          49
#
#    m_dep  mobile_wt  ...   pc  px_height  px_width   ram  sc_h  sc_w  \
# 0    0.1        193  ...   16        226      1412  3476    12     7
# 1    0.8        191  ...   12        746       857  3895     6     0
# 2    0.9        186  ...    4       1270      1366  2396    17    10
# 3    0.5         96  ...   20        295      1752  3893    10     0
# 4    0.5        108  ...   18        749       810  1773    15     8
#
#    talk_time  three_g  touch_screen  wifi
# 0          2        0             1     0
# ...

# %%
#df2.drop('mobile_wt',inplace=True,axis=1)
#df2.drop('three_g',inplace=True,axis=1)
#df2.drop('m_dep',inplace=True,axis=1)
#df2.drop('blue',inplace=True,axis=1)
#df2.drop('talk_time',inplace=True,axis=1)
#df2.drop('wifi',inplace=True,axis=1)
#X_test=df2.drop('id',axis=1)
#df2=df2[['id','battery_power','clock_speed','fc','int_memory', 'm_dep', 'mobile_wt','pc', 'px_height','px_width', 'ram', 'sc_h', 'sc_w', 'talk_time','n_cores']]
df2=df2[['id','battery_power','int_memory', 'mobile_wt', 'px_height','px_width', 'ram', 'sc_w', 'talk_time']]

sc.fit(df2.drop('id',axis=1))
X_test = sc.transform(df2.drop('id',axis=1))

#principalcomptest=pca.fit_transform(X_test)
#principalcomptest.shape

# %%
output1=grid.predict(X_test)

# %%
df4=pd.DataFrame(data=df2['id'],columns=['id'])

# %%
df4['price_range']=output1

# %%
df4.to_csv('submission_1.csv')

# %%
df4
# Out:
#        id  price_range
# 0       1            3
# 1       2            3
# 2       3            2
# 3       4            3
# 4       5            1
# 5       6            3
# 6       7            3
# 7       8            1
# 8       9            3
# 9      10            0
# 10     11            3
# 11     12            3
# 12     13            0
# 13     14            0
# 14     15            2
# 15     16            0
# 16     17            2
# 17     18            1
# 18     19            3
# 19     20            2
# 20     21            1
# 21     22            3
# 22     23            1
# 23     24            1
# 24     25            3
# 25     26            0
# 26     27            2
# 27     28            0
# 28     29            3
# 29     30            0
# ..    ...          ...
# 970   971            2
# 971   972            1
# 972   973            2
# 973   974            1
# 974   975            3
# 975   976            1
# 976   977            1
# 977   978            3
# ...
